# %%
arcpy.management.JoinField(
    in_data="CI_District_2021_RGEE",
    in_field="CodDistric",
    join_table="BTP_District",
    join_field="carto_code_district",
    fields="BTP_1;BTP_2",
    fm_option="NOT_USE_FM",
    field_mapping=None,
    index_join_fields="NO_INDEXES"
)
# Out:
# <Result 'CI_District_2021_RGEE'>

# %%
# DEBUT AVEC GIT
